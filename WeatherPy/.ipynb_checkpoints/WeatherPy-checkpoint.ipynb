# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy import stats
import gmaps
import csv
import os
import random
from citipy import citipy


# Import API key
from api_keys import weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
cities=[]
lat_long=[]
lat=np.random.uniform(-90,90,1500)
long=np.random.uniform(-180,180,1500)
lat_long=zip(lat,long)

for lat_long in lat_long:
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    if city not in cities:
        cities.append(city)
cities

# calculate length cities
len(cities)
# Out:
# 602

# %%
import json

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units="metric"

# Build partial query URL
query_url = url+"appid="+weather_api_key+"&units="+units+"&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import json

Lat=[]
Lng=[]
City=[]
Cloudiness=[]
Country=[]
Date=[]
Humidity=[]
Max_Temp=[]
Wind_Speed=[]

counter=0
print("Beginning Data Retrieval")
print("-------------------------")

for city in cities:
    response = requests.get(query_url + city).json()
    if counter < 5:
        counter+=1
    else:
        counter=0 
    print("Processing Record {} | {}".format(counter,city))
    try:
        Lat.append(response['coord']['lat'])
        Max_Temp.append(response['main']['temp_max'])
        Lng.append(response['coord']['lon'])
        City.append(city)
        Wind_Speed.append(response['wind']['speed'])
        Humidity.append(response['main']['humidity'])
        Date.append(response['dt'])
        Country.append(response['sys']['country'])
        Cloudiness.append(response['clouds']['all'])
        
    except KeyError:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 | kahului
# Processing Record 2 | butaritari
# Processing Record 3 | albany
# Processing Record 4 | hermanus
# Processing Record 5 | mataura
# Processing Record 0 | taolanaro
# City not found. Skipping...
# Processing Record 1 | castro
# Processing Record 2 | fortuna
# Processing Record 3 | ogre
# Processing Record 4 | vaini
# Processing Record 5 | carnarvon
# Processing Record 0 | grand river south east
# City not found. Skipping...
# Processing Record 1 | kavieng
# Processing Record 2 | fuxin
# Processing Record 3 | cabo san lucas
# Processing Record 4 | tiksi
# Processing Record 5 | chongwe
# Processing Record 0 | leningradskiy
# Processing Record 1 | kapaa
# Processing Record 2 | tadine
# Processing Record 3 | deputatskiy
# Processing Record 4 | san nicolas
# Processing Record 5 | clyde river
# Processing Record 0 | bollnas
# Processing Record 1 | punta arenas
# Processing Record 2 | rikitea
# Processing Record 3 | mar del plata
# Processing Record 4 | ruatoria
# City not found. Skipping...
# Processing Record 5 | ligayan
# Processing Record 0 | carauari
# Processing Record 1 | kloulklubed
# Processing Record 2 | lebu
# Processing Record 3 | jamestown
# Processing Record 4 | ushuaia
# Processing Record 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 0 | nelson bay
# Processing Record 1 | broken hill
# Processing Record 2 | fauske
# Processing Record 3 | kasongo-lunda
# Processing Record 4 | sur
# Processing Record 5 | taloda
# Processing Record 0 | port elizabeth
# Processing Record 1 | ribeira grande
# Processing Record 2 | jacareacanga
# Processing Record 3 | qaanaaq
# Processing Record 4 | mount isa
# Processing Record 5 | concepcion del uruguay
# Processing Record 0 | mundo nuevo
# Processing Record 1 | madimba
# Processing Record 2 | huarmey
# Processing Record 3 | busselton
# Processing Record 4 | mbini
# Processing Record 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 0 | bredasdorp
# Processing Record 1 | atuona
# Processing Record 2 | bubaque
# Processing Record 3 | naze
# Processing Record 4 | tambun
# Processing Record 5 | ambon
# Processing Record 0 | okhtyrka
# Processing Record 1 | halalo
# City not found. Skipping...
# Processing Record 2 | saint-philippe
# Processing Record 3 | surin
# Processing Record 4 | vestmannaeyjar
# Processing Record 5 | dormidontovka
# Processing Record 0 | muncar
# Processing Record 1 | gladstone
# Processing Record 2 | dubti
# Processing Record 3 | zhezkazgan
# Processing Record 4 | roma
# Processing Record 5 | tongren
# Processing Record 0 | nikolskoye
# Processing Record 1 | komsomolskiy
# Processing Record 2 | zhanakorgan
# Processing Record 3 | sambava
# Processing Record 4 | caucaia
# Processing Record 5 | samarinda
# Processing Record 0 | saint george
# Processing Record 1 | arman
# Processing Record 2 | burica
# City not found. Skipping...
# Processing Record 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 | longyearbyen
# Processing Record 5 | tuktoyaktuk
# Processing Record 0 | torquay
# Processing Record 1 | ponta do sol
# Processing Record 2 | ningxiang
# Processing Record 3 | yellowknife
# Processing Record 4 | avarua
# Processing Record 5 | saldanha
# Processing Record 0 | najran
# Processing Record 1 | comodoro rivadavia
# Processing Record 2 | hilo
# Processing Record 3 | ponta delgada
# Processing Record 4 | mapiripan
# Processing Record 5 | college
# Processing Record 0 | victoria
# Processing Record 1 | tucuman
# Processing Record 2 | grover beach
# Processing Record 3 | olga
# Processing Record 4 | chuy
# Processing Record 5 | dikson
# Processing Record 0 | nalut
# Processing Record 1 | atambua
# Processing Record 2 | cape town
# Processing Record 3 | henties bay
# Processing Record 4 | bandar-e lengeh
# Processing Record 5 | nouadhibou
# Processing Record 0 | himora
# City not found. Skipping...
# Processing Record 1 | yulara
# Processing Record 2 | esperance
# Processing Record 3 | coquimbo
# Processing Record 4 | hasaki
# Processing Record 5 | rensvik
# Processing Record 0 | hambantota
# Processing Record 1 | otta
# Processing Record 2 | tsihombe
# City not found. Skipping...
# Processing Record 3 | amahai
# Processing Record 4 | genhe
# Processing Record 5 | mandalgovi
# Processing Record 0 | iwaki
# Processing Record 1 | samarai
# Processing Record 2 | puerto ayacucho
# Processing Record 3 | kaitangata
# Processing Record 4 | guerrero negro
# Processing Record 5 | nanortalik
# Processing Record 0 | komotini
# Processing Record 1 | hobart
# Processing Record 2 | ilulissat
# Processing Record 3 | bluff
# Processing Record 4 | maarianhamina
# Processing Record 5 | saskylakh
# Processing Record 0 | tixtla
# City not found. Skipping...
# Processing Record 1 | remigio
# Processing Record 2 | tashtyp
# Processing Record 3 | yokadouma
# Processing Record 4 | luderitz
# Processing Record 5 | ewa beach
# Processing Record 0 | polunochnoye
# Processing Record 1 | chilliwack
# Processing Record 2 | portland
# Processing Record 3 | srednekolymsk
# Processing Record 4 | salta
# Processing Record 5 | porto nacional
# Processing Record 0 | kavaratti
# Processing Record 1 | patti
# Processing Record 2 | saint-augustin
# Processing Record 3 | arraial do cabo
# Processing Record 4 | attawapiskat
# City not found. Skipping...
# Processing Record 5 | ambilobe
# Processing Record 0 | port hedland
# Processing Record 1 | yurla
# Processing Record 2 | japura
# Processing Record 3 | lerwick
# Processing Record 4 | puerto ayora
# Processing Record 5 | reefton
# City not found. Skipping...
# Processing Record 0 | zig
# Processing Record 1 | kaeo
# Processing Record 2 | vila velha
# Processing Record 3 | souillac
# Processing Record 4 | maracaju
# Processing Record 5 | mana
# Processing Record 0 | klaksvik
# Processing Record 1 | georgiyevka
# Processing Record 2 | port macquarie
# Processing Record 3 | pauini
# Processing Record 4 | hovd
# Processing Record 5 | inzhavino
# Processing Record 0 | wilmington
# Processing Record 1 | mahebourg
# Processing Record 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 | san andres
# Processing Record 4 | georgetown
# Processing Record 5 | vardo
# Processing Record 0 | trincomalee
# Processing Record 1 | saint-pierre
# Processing Record 2 | berlevag
# Processing Record 3 | hudiksvall
# Processing Record 4 | dali
# Processing Record 5 | kudahuvadhoo
# Processing Record 0 | traverse city
# Processing Record 1 | nehe
# Processing Record 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 | san patricio
# Processing Record 4 | sungaipenuh
# Processing Record 5 | bethel
# Processing Record 0 | natitingou
# Processing Record 1 | codrington
# Processing Record 2 | tumannyy
# City not found. Skipping...
# Processing Record 3 | jeremie
# Processing Record 4 | plouzane
# Processing Record 5 | waipawa
# Processing Record 0 | liwale
# Processing Record 1 | barrow
# Processing Record 2 | tasiilaq
# Processing Record 3 | norman wells
# Processing Record 4 | lander
# Processing Record 5 | pisco
# Processing Record 0 | antsohihy
# Processing Record 1 | kosh-agach
# Processing Record 2 | lakes entrance
# Processing Record 3 | aykhal
# Processing Record 4 | vila franca do campo
# Processing Record 5 | bengkulu
# Processing Record 0 | aksha
# Processing Record 1 | porto novo
# Processing Record 2 | duvan
# Processing Record 3 | chokurdakh
# Processing Record 4 | vagur
# Processing Record 5 | evensk
# Processing Record 0 | grand gaube
# Processing Record 1 | the valley
# Processing Record 2 | baculin
# Processing Record 3 | martinsicuro
# Processing Record 4 | severo-kurilsk
# Processing Record 5 | valparaiso
# Processing Record 0 | prabumulih
# Processing Record 1 | port alfred
# Processing Record 2 | geraldton
# Processing Record 3 | new norfolk
# Processing Record 4 | jiangyou
# Processing Record 5 | faanui
# Processing Record 0 | colares
# Processing Record 1 | salalah
# Processing Record 2 | toora-khem
# Processing Record 3 | okhotsk
# Processing Record 4 | teya
# Processing Record 5 | hangzhou
# Processing Record 0 | pandan
# Processing Record 1 | mnogovershinnyy
# Processing Record 2 | zaozerne
# Processing Record 3 | namibe
# Processing Record 4 | dunedin
# Processing Record 5 | shingu
# Processing Record 0 | lorengau
# Processing Record 1 | acari
# Processing Record 2 | fort nelson
# Processing Record 3 | meyungs
# City not found. Skipping...
# Processing Record 4 | musoma
# Processing Record 5 | salinopolis
# Processing Record 0 | cabedelo
# Processing Record 1 | east london
# Processing Record 2 | bambous virieux
# Processing Record 3 | puerto el triunfo
# Processing Record 4 | necochea
# Processing Record 5 | kualakapuas
# Processing Record 0 | tosya
# Processing Record 1 | phonhong
# Processing Record 2 | nuuk
# Processing Record 3 | dwarka
# Processing Record 4 | acapulco
# Processing Record 5 | bairiki
# Processing Record 0 | banjar
# Processing Record 1 | upernavik
# Processing Record 2 | san rafael
# Processing Record 3 | daxian
# City not found. Skipping...
# Processing Record 4 | altamira
# Processing Record 5 | aripuana
# Processing Record 0 | sao desiderio
# Processing Record 1 | kabwe
# Processing Record 2 | straumen
# Processing Record 3 | diamantino
# Processing Record 4 | kawalu
# Processing Record 5 | taltal
# Processing Record 0 | cap malheureux
# Processing Record 1 | yumen
# Processing Record 2 | faya
# Processing Record 3 | kruisfontein
# Processing Record 4 | gracac
# Processing Record 5 | cortez
# Processing Record 0 | aklavik
# Processing Record 1 | chapais
# Processing Record 2 | toliary
# City not found. Skipping...
# Processing Record 3 | isangel
# Processing Record 4 | bay roberts
# Processing Record 5 | touros
# Processing Record 0 | tutoia
# Processing Record 1 | morrisburg
# Processing Record 2 | carballo
# Processing Record 3 | tromso
# Processing Record 4 | hithadhoo
# Processing Record 5 | polson
# Processing Record 0 | temiscaming
# Processing Record 1 | ngukurr
# City not found. Skipping...
# Processing Record 2 | tura
# Processing Record 3 | balimo
# City not found. Skipping...
# Processing Record 4 | beyneu
# Processing Record 5 | honiara
# Processing Record 0 | gouyave
# Processing Record 1 | launceston
# Processing Record 2 | pevek
# Processing Record 3 | waingapu
# Processing Record 4 | port-cartier
# Processing Record 5 | gumrak
# Processing Record 0 | dixon
# Processing Record 1 | snasa
# Processing Record 2 | vaitupu
# City not found. Skipping...
# Processing Record 3 | katsuura
# Processing Record 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 | torbay
# Processing Record 0 | delijan
# Processing Record 1 | namatanai
# Processing Record 2 | alofi
# Processing Record 3 | rawson
# Processing Record 4 | aswan
# Processing Record 5 | wilkie
# Processing Record 0 | sagauli
# Processing Record 1 | berdigestyakh
# Processing Record 2 | alyangula
# Processing Record 3 | shahrud
# Processing Record 4 | sola
# Processing Record 5 | dhanbad
# Processing Record 0 | bicester
# Processing Record 1 | khatanga
# Processing Record 2 | grindavik
# Processing Record 3 | amderma
# City not found. Skipping...
# Processing Record 4 | kushmurun
# Processing Record 5 | ola
# Processing Record 0 | aksarka
# Processing Record 1 | cherskiy
# Processing Record 2 | peniche
# Processing Record 3 | sao joao da barra
# Processing Record 4 | inverell
# Processing Record 5 | yerbogachen
# Processing Record 0 | sukpak
# Processing Record 1 | pangnirtung
# Processing Record 2 | dawei
# Processing Record 3 | loandjili
# Processing Record 4 | arlit
# Processing Record 5 | antalaha
# Processing Record 0 | yar-sale
# Processing Record 1 | coihaique
# Processing Record 2 | nome
# Processing Record 3 | monte carmelo
# Processing Record 4 | aksarayskiy
# Processing Record 5 | balabac
# Processing Record 0 | bilibino
# Processing Record 1 | havoysund
# Processing Record 2 | jacksonville
# Processing Record 3 | krasnoarmeysk
# Processing Record 4 | vanimo
# Processing Record 5 | haines junction
# Processing Record 0 | jiuquan
# Processing Record 1 | santa maria do suacui
# Processing Record 2 | salem
# Processing Record 3 | humaita
# Processing Record 4 | malanje
# Processing Record 5 | barillas
# Processing Record 0 | chunskiy
# Processing Record 1 | leo
# Processing Record 2 | quelimane
# Processing Record 3 | vao
# Processing Record 4 | duluth
# Processing Record 5 | marcona
# City not found. Skipping...
# Processing Record 0 | troitskoye
# Processing Record 1 | nata
# Processing Record 2 | sinnamary
# Processing Record 3 | tekkali
# Processing Record 4 | mariakani
# Processing Record 5 | half moon bay
# Processing Record 0 | maravilha
# Processing Record 1 | kharan
# Processing Record 2 | shihezi
# Processing Record 3 | puerto quijarro
# Processing Record 4 | vostok
# Processing Record 5 | madison
# Processing Record 0 | sept-iles
# Processing Record 1 | biltine
# Processing Record 2 | surt
# Processing Record 3 | beringovskiy
# Processing Record 4 | te anau
# Processing Record 5 | darnah
# Processing Record 0 | chudovo
# Processing Record 1 | margate
# Processing Record 2 | port hardy
# Processing Record 3 | bandarbeyla
# Processing Record 4 | fairbanks
# Processing Record 5 | cidreira
# Processing Record 0 | nevsehir
# Processing Record 1 | edgewater
# Processing Record 2 | santiago de las vegas
# Processing Record 3 | sal rei
# Processing Record 4 | boden
# Processing Record 5 | balint
# Processing Record 0 | tulsipur
# Processing Record 1 | krasnoselkup
# Processing Record 2 | dosso
# Processing Record 3 | seaford
# Processing Record 4 | leh
# Processing Record 5 | zhicheng
# Processing Record 0 | verkhnyaya inta
# Processing Record 1 | vila praia de ancora
# Processing Record 2 | ust-maya
# Processing Record 3 | morrinhos
# Processing Record 4 | narsaq
# Processing Record 5 | corner brook
# Processing Record 0 | andros town
# Processing Record 1 | ixtapa
# Processing Record 2 | barabai
# Processing Record 3 | mercedes
# Processing Record 4 | zelhem
# Processing Record 5 | kroderen
# City not found. Skipping...
# Processing Record 0 | saleaula
# City not found. Skipping...
# Processing Record 1 | coremas
# Processing Record 2 | port lincoln
# Processing Record 3 | yagodnoye
# Processing Record 4 | coos bay
# Processing Record 5 | meulaboh
# Processing Record 0 | iracoubo
# Processing Record 1 | calbuco
# Processing Record 2 | uyemskiy
# Processing Record 3 | bam
# Processing Record 4 | udachnyy
# Processing Record 5 | fukue
# Processing Record 0 | marathon
# Processing Record 1 | rio sereno
# Processing Record 2 | kurdzhinovo
# Processing Record 3 | yunjinghong
# City not found. Skipping...
# Processing Record 4 | vikravandi
# Processing Record 5 | tilichiki
# Processing Record 0 | san policarpo
# Processing Record 1 | kodiak
# Processing Record 2 | flinders
# Processing Record 3 | caravelas
# Processing Record 4 | chumikan
# Processing Record 5 | shache
# Processing Record 0 | bayeux
# Processing Record 1 | tuatapere
# Processing Record 2 | havelock
# Processing Record 3 | rongcheng
# Processing Record 4 | alice springs
# Processing Record 5 | prado
# Processing Record 0 | ancud
# Processing Record 1 | sao sepe
# Processing Record 2 | weihai
# Processing Record 3 | bara
# Processing Record 4 | chimbote
# Processing Record 5 | parras
# City not found. Skipping...
# Processing Record 0 | rio grande
# Processing Record 1 | sungairaya
# Processing Record 2 | villarrica
# Processing Record 3 | dakar
# Processing Record 4 | paamiut
# Processing Record 5 | navolato
# Processing Record 0 | bolobo
# Processing Record 1 | novo aripuana
# Processing Record 2 | bambanglipuro
# Processing Record 3 | catamarca
# Processing Record 4 | kieta
# Processing Record 5 | wanaka
# Processing Record 0 | trairi
# Processing Record 1 | thompson
# Processing Record 2 | sinazongwe
# Processing Record 3 | asau
# Processing Record 4 | qaqortoq
# Processing Record 5 | mouzakion
# City not found. Skipping...
# Processing Record 0 | manakara
# Processing Record 1 | macae
# Processing Record 2 | ciudad bolivar
# Processing Record 3 | hartford
# Processing Record 4 | galle
# Processing Record 5 | puerto baquerizo moreno
# Processing Record 0 | dabakala
# Processing Record 1 | buraydah
# Processing Record 2 | wahran
# City not found. Skipping...
# Processing Record 3 | portsmouth
# Processing Record 4 | halifax
# Processing Record 5 | gari
# Processing Record 0 | la ronge
# Processing Record 1 | plettenberg bay
# Processing Record 2 | berbera
# Processing Record 3 | sitka
# Processing Record 4 | karnobat
# Processing Record 5 | wellington
# Processing Record 0 | agua verde
# Processing Record 1 | samusu
# City not found. Skipping...
# Processing Record 2 | talnakh
# Processing Record 3 | high prairie
# Processing Record 4 | marsh harbour
# Processing Record 5 | provideniya
# Processing Record 0 | ardistan
# City not found. Skipping...
# Processing Record 1 | massaguet
# Processing Record 2 | wasilla
# Processing Record 3 | camana
# Processing Record 4 | kabare
# Processing Record 5 | ferrol
# Processing Record 0 | benguela
# Processing Record 1 | umzimvubu
# City not found. Skipping...
# Processing Record 2 | ovalle
# Processing Record 3 | natal
# Processing Record 4 | sobolevo
# Processing Record 5 | lasa
# Processing Record 0 | wajir
# Processing Record 1 | kovdor
# Processing Record 2 | pacific grove
# Processing Record 3 | sao filipe
# Processing Record 4 | uige
# Processing Record 5 | negru voda
# Processing Record 0 | barentu
# Processing Record 1 | lompoc
# Processing Record 2 | hamilton
# Processing Record 3 | urucui
# Processing Record 4 | gaoua
# Processing Record 5 | vila
# Processing Record 0 | puerto leguizamo
# Processing Record 1 | mount gambier
# Processing Record 2 | konstantinovka
# Processing Record 3 | rungata
# City not found. Skipping...
# Processing Record 4 | menongue
# Processing Record 5 | shelburne
# Processing Record 0 | airai
# Processing Record 1 | baft
# Processing Record 2 | moa
# Processing Record 3 | le vauclin
# Processing Record 4 | olmos
# Processing Record 5 | puerto del rosario
# Processing Record 0 | xiantao
# Processing Record 1 | champerico
# Processing Record 2 | barawe
# City not found. Skipping...
# Processing Record 3 | sovetskiy
# Processing Record 4 | seminole
# Processing Record 5 | paraiso
# Processing Record 0 | alpiarca
# Processing Record 1 | sechura
# Processing Record 2 | tessalit
# Processing Record 3 | hailar
# Processing Record 4 | lavrentiya
# Processing Record 5 | svobodnyy
# Processing Record 0 | tunduru
# City not found. Skipping...
# Processing Record 1 | shambu
# Processing Record 2 | stonewall
# Processing Record 3 | maniitsoq
# Processing Record 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 | petukhovo
# Processing Record 0 | obo
# Processing Record 1 | morondava
# Processing Record 2 | auki
# Processing Record 3 | wanning
# Processing Record 4 | matara
# Processing Record 5 | apollonia
# Processing Record 0 | strangnas
# Processing Record 1 | ilheus
# Processing Record 2 | sangamner
# Processing Record 3 | san cristobal
# Processing Record 4 | kinango
# Processing Record 5 | tsurugi
# Processing Record 0 | karauzyak
# City not found. Skipping...
# Processing Record 1 | estelle
# Processing Record 2 | panuco
# Processing Record 3 | batemans bay
# Processing Record 4 | betioky
# Processing Record 5 | pieve di soligo
# Processing Record 0 | iralaya
# Processing Record 1 | kupiskis
# Processing Record 2 | arkhipo-osipovka
# Processing Record 3 | lebedinyy
# Processing Record 4 | hirara
# Processing Record 5 | mishan
# Processing Record 0 | paratinga
# Processing Record 1 | olbia
# Processing Record 2 | kalabo
# Processing Record 3 | ridgecrest
# Processing Record 4 | baruun-urt
# Processing Record 5 | walvis bay
# Processing Record 0 | sorland
# Processing Record 1 | verkhoyansk
# Processing Record 2 | helena
# Processing Record 3 | lazaro cardenas
# Processing Record 4 | tutzing
# Processing Record 5 | grenville
# Processing Record 0 | beian
# Processing Record 1 | nova olinda do norte
# Processing Record 2 | lolua
# City not found. Skipping...
# Processing Record 3 | campbell river
# Processing Record 4 | byron bay
# Processing Record 5 | imeni poliny osipenko
# Processing Record 0 | kirgiz-miyaki
# Processing Record 1 | fort frances
# Processing Record 2 | davila
# Processing Record 3 | farkhor
# Processing Record 4 | tiznit
# Processing Record 5 | cordoba
# Processing Record 0 | bogorodskoye
# Processing Record 1 | vestmanna
# Processing Record 2 | hofn
# Processing Record 3 | dicabisagan
# Processing Record 4 | bujumbura
# Processing Record 5 | marawi
# Processing Record 0 | thinadhoo
# Processing Record 1 | labuhan
# Processing Record 2 | viedma
# Processing Record 3 | stykkisholmur
# Processing Record 4 | kulhudhuffushi
# Processing Record 5 | fortuna foothills
# Processing Record 0 | panama city
# Processing Record 1 | aiquile
# Processing Record 2 | penzance
# Processing Record 3 | makakilo city
# Processing Record 4 | constitucion
# Processing Record 5 | pueblo
# Processing Record 0 | ngaoundere
# Processing Record 1 | les cayes
# Processing Record 2 | kitob

# %%
Lng
# Out:
# [-156.47,
#  172.7902,
#  -73.9662,
#  19.2345,
#  168.8643,
#  -50.0119,
#  -124.1573,
#  24.614,
#  -175.2,
#  113.6333,
#  150.7967,
#  121.6589,
#  -109.9124,
#  128.8694,
#  28.682,
#  178.4167,
#  -159.319,
#  167.8833,
#  139.9,
#  120.5953,
#  -68.5914,
#  16.3946,
#  -70.9167,
#  -134.9692,
#  -57.5575,
#  119.4706,
#  -66.8958,
#  134.2556,
#  -73.65,
#  -79.2353,
#  -68.3,
#  152.15,
#  141.4333,
#  15.3918,
#  16.8167,
#  59.5289,
#  74.2167,
#  25.5701,
#  -28.7,
#  -57.7528,
#  -69.3632,
#  139.5,
#  -58.2372,
#  -95.5,
#  40.3333,
#  -78.1522,
#  115.3333,
#  9.6134,
#  20.0403,
#  -139.0333,
#  -15.8333,
#  129.4833,
#  107.0712,
#  128.1814,
#  34.8988,
#  55.7679,
#  103.4936,
#  -20.2734,
#  134.9076,
#  114.3333,
#  151.25,
#  41.0853,
#  67.7144,
#  -75.4557,
#  109.1853,
#  30.7861,
#  71.7189,
#  67.2495,
#  50.1667,
#  -38.6531,
#  117.15,
#  -113.5841,
#  150.1667,
#  15.6401,
#  -133.0374,
#  -3.5143,
#  -17.1,
#  111.2052,
#  -114.3525,
#  -159.775,
#  17.9442,
#  44.1277,
#  -67.5,
#  -155.09,
#  -25.6667,
#  -72.1256,
#  -147.8028,
#  114.1577,
#  -65.2226,
#  -120.6213,
#  135.2892,
#  -53.4616,
#  80.5464,
#  10.85,
#  124.8925,
#  18.4232,
#  14.2845,
#  54.8807,
#  -17.0347,
#  130.9889,
#  121.9,
#  -71.3436,
#  140.8333,
#  7.8167,
#  81.1185,
#  9.5353,
#  128.9167,
#  121.5167,
#  106.2708,
#  140.8833,
#  150.6667,
#  -67.6236,
#  169.8464,
#  -114.0611,
#  -45.2371,
#  25.3964,
#  147.3294,
#  -51.1,
#  168.3333,
#  19.9348,
#  114.0833,
#  -35.7833,
#  89.8983,
#  15.05,
#  15.1594,
#  -158.0072,
#  60.4153,
#  -121.9443,
#  -122.6762,
#  153.6833,
#  -65.4117,
#  -48.4172,
#  72.642,
#  74.8572,
#  -58.6502,
#  -42.0278,
#  49.05,
#  118.5667,
#  54.3223,
#  102.35,
#  -1.1494,
#  -90.3518,
#  -92.7663,
#  173.7833,
#  -40.2925,
#  57.5167,
#  -55.1683,
#  -53.7767,
#  -6.589,
#  74.7114,
#  152.9167,
#  -66.9764,
#  91.6419,
#  42.4937,
#  -77.9447,
#  57.7,
#  -81.7006,
#  100.3354,
#  31.1107,
#  81.2335,
#  55.4781,
#  29.0864,
#  17.1036,
#  100.1833,
#  72.8944,
#  -85.6206,
#  124.8333,
#  -97.5169,
#  101.3833,
#  -73.414,
#  1.3796,
#  141.9667,
#  -74.1167,
#  -4.6167,
#  175.5153,
#  37.9333,
#  -156.7887,
#  -37.6368,
#  -126.8329,
#  -108.7307,
#  -76.2167,
#  47.9875,
#  88.6667,
#  147.981,
#  111.5,
#  -25.4333,
#  102.2655,
#  113.2867,
#  2.6036,
#  57.9024,
#  147.9167,
#  -6.8119,
#  159.2333,
#  57.6608,
#  -63.0578,
#  126.5842,
#  13.9145,
#  156.125,
#  -71.6273,
#  104.25,
#  26.891,
#  114.6,
#  147.0587,
#  104.7167,
#  -151.75,
#  -9.4469,
#  54.0924,
#  96.11,
#  143.3,
#  92.6267,
#  120.1614,
#  124.1694,
#  139.9242,
#  33.2787,
#  12.1522,
#  170.5036,
#  135.9833,
#  147.2712,
#  -74.6158,
#  -122.7002,
#  33.8,
#  -47.3561,
#  -34.8339,
#  27.9116,
#  57.7575,
#  -88.55,
#  -58.7368,
#  114.3876,
#  34.0401,
#  102.4166,
#  -51.7216,
#  68.9678,
#  -99.8901,
#  172.9752,
#  114.9675,
#  -56.1549,
#  -68.3301,
#  -52.2064,
#  -60.6333,
#  -44.9733,
#  28.4464,
#  11.2999,
#  -56.4461,
#  108.2082,
#  -70.4833,
#  57.6142,
#  97.2,
#  42.4509,
#  24.7314,
#  15.8547,
#  -108.5859,
#  -135.0107,
#  -74.8492,
#  169.2667,
#  -53.2648,
#  -35.4608,
#  -42.2744,
#  -75.1826,
#  -8.691,
#  18.957,
#  73.0833,
#  -114.1632,
#  -79.0971,
#  90.2201,
#  55.2,
#  159.95,
#  -61.7296,
#  147.1667,
#  170.3133,
#  120.2641,
#  -66.8654,
#  44.3824,
#  -121.8233,
#  12.3778,
#  140.3,
#  -52.7314,
#  50.6838,
#  152.4333,
#  -169.9187,
#  -65.1023,
#  32.907,
#  -108.7014,
#  84.7333,
#  126.6992,
#  136.4192,
#  54.9763,
#  167.55,
#  86.45,
#  -1.1536,
#  102.5,
#  -22.4338,
#  64.6311,
#  151.2833,
#  67.7975,
#  161.3,
#  -9.3811,
#  -41.0511,
#  151.1167,
#  108.0108,
#  94.6333,
#  -65.7125,
#  98.2,
#  11.8578,
#  7.3853,
#  50.2788,
#  70.8333,
#  -72.0662,
#  -165.4064,
#  -47.4986,
#  48.0119,
#  117.0645,
#  166.4372,
#  24.6622,
#  -81.6556,
#  45.6969,
#  141.3028,
#  -137.5108,
#  98.5174,
#  -42.4142,
#  78.1667,
#  -63.0208,
#  16.341,
#  -91.3158,
#  99.6342,
#  -2.1,
#  36.8883,
#  167.4833,
#  -92.1066,
#  84.6757,
#  -80.5167,
#  -52.95,
#  84.2333,
#  39.4736,
#  -122.4286,
#  -53.1725,
#  65.4167,
#  86.0333,
#  -57.7667,
#  135.8833,
#  -86.5667,
#  -66.3821,
#  20.9167,
#  16.5887,
#  179.3167,
#  167.7167,
#  22.6367,
#  31.6833,
#  1.3862,
#  -127.4199,
#  50.8122,
#  -147.7164,
#  -50.2056,
#  34.6667,
#  -80.9023,
#  -82.3869,
#  -22.9167,
#  21.6886,
#  21.8536,
#  82.2973,
#  82.4667,
#  3.1937,
#  0.1027,
#  77.5833,
#  111.5047,
#  60.3094,
#  -8.8526,
#  134.5333,
#  -49.0994,
#  -46.05,
#  -57.9484,
#  -77.7667,
#  -105.2,
#  115.3833,
#  -59.4307,
#  6.3486,
#  -37.9458,
#  135.8667,
#  149.6667,
#  -124.2179,
#  96.1285,
#  -53.2011,
#  -73.1273,
#  40.8524,
#  58.357,
#  112.4,
#  128.8419,
#  -89.7668,
#  -82.8667,
#  40.9552,
#  79.55,
#  166.1,
#  125.5072,
#  -152.4072,
#  150.8552,
#  -39.2481,
#  135.315,
#  77.2406,
#  -34.9322,
#  167.6833,
#  -76.9013,
#  117.8517,
#  133.8833,
#  -39.2208,
#  -73.8203,
#  -53.5653,
#  122.1136,
#  10.7288,
#  -78.5783,
#  -52.0986,
#  108.9,
#  -56.4333,
#  -17.4441,
#  -49.6678,
#  -107.6944,
#  16.2333,
#  -60.3797,
#  110.2833,
#  -65.7852,
#  155.6333,
#  169.15,
#  -39.2689,
#  -97.8558,
#  27.4618,
#  26.4,
#  -46.0333,
#  48.0167,
#  -41.7869,
#  -63.5497,
#  -72.7662,
#  80.217,
#  -89.6,
#  -4.4333,
#  43.975,
#  -1.0913,
#  -63.5724,
#  62.3497,
#  -105.2842,
#  23.3716,
#  45.0143,
#  -135.33,
#  26.9833,
#  174.7756,
#  -106.05,
#  88.3972,
#  -116.4858,
#  -77.0636,
#  -173.3,
#  15.4365,
#  -149.4394,
#  -72.7111,
#  28.8242,
#  -8.2369,
#  13.4055,
#  -71.2003,
#  -35.2094,
#  31.8996,
#  10.7002,
#  40.0573,
#  30.4758,
#  -121.9166,
#  -24.4956,
#  15.0613,
#  28.2,
#  37.5928,
#  -120.4579,
#  -84.5333,
#  -44.5561,
#  -3.2508,
#  -8.1588,
#  -74.7819,
#  140.7667,
#  127.9833,
#  17.691,
#  -80.2041,
#  125.4092,
#  56.6057,
#  -74.9403,
#  -60.8388,
#  -79.7453,
#  -13.8627,
#  113.4,
#  -91.9167,
#  63.5842,
#  -81.2081,
#  -83.8656,
#  -8.5819,
#  -80.8222,
#  1.0114,
#  119.7,
#  -171,
#  128.1333,
#  37.1,
#  -97.3268,
#  -52.9,
#  67.9019,
#  26.4869,
#  44.2833,
#  160.7034,
#  110.3967,
#  80.5353,
#  24.7231,
#  17.0312,
#  -39.0494,
#  74.2167,
#  -72.225,
#  39.3153,
#  136.6333,
#  -90.1067,
#  -98.1667,
#  150.1833,
#  44.3833,
#  12.1772,
#  -83.2333,
#  24.9667,
#  38.52,
#  125.5167,
#  125.2833,
#  131.8833,
#  -43.1842,
#  9.4856,
#  22.6814,
#  -117.6709,
#  113.2792,
#  14.5053,
#  12.6934,
#  133.385,
#  -112.0361,
#  -102.2,
#  11.2803,
#  -61.6167,
#  9.5683,
#  -59.0942,
#  -125.2446,
#  153.6167,
#  136.4853,
#  54.7979,
#  -93.4003,
#  120.5763,
#  69.4036,
#  -9.5,
#  -64.1811,
#  37.8833,
#  -7.1664,
#  -15.2082,
#  122.4157,
#  29.3644,
#  124.2928,
#  72.9333,
#  112.2051,
#  -62.9967,
#  -22.7297,
#  73.07,
#  -114.4119,
#  -79.5197,
#  -65.1807,
#  -5.5371,
#  -158.0858,
#  -72.4167,
#  -104.6091,
#  13.5833,
#  -73.75,
#  66.8332]

# %%
response
# Out:
# {'coord': {'lon': 66.8332, 'lat': 39.0843},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 9,
#   'feels_like': 5.56,
#   'temp_min': 9,
#   'temp_max': 9,
#   'pressure': 1019,
#   'humidity': 53},
#  'visibility': 6000,
#  'wind': {'speed': 2.06, 'deg': 180},
#  'clouds': {'all': 0},
#  'dt': 1611084271,
#  'sys': {'type': 1,
#   'id': 9013,
#   'country': 'UZ',
#   'sunrise': 1611110877,
#   'sunset': 1611146340},
#  'timezone': 18000,
#  'id': 1216787,
#  'name': 'Kitob',
#  'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_dict={
    "City":City,
    "Lat":Lat,
    "Lng":Lng,
    "Max_Temp": Max_Temp ,
    "Humidity":Humidity,
    "Cloudiness":Cloudiness,
    "Wind_Speed":Wind_Speed,
    "Country":Country,
    "Date":Date
}

city_weather_df=pd.DataFrame.from_dict(city_weather_dict,orient='index')
city_weather_df=city_weather_df.transpose()
city_weather_df
# Out:
#              City      Lat      Lng Max_Temp Humidity Cloudiness Wind_Speed  \
# 0         kahului  20.8947  -156.47    22.22       73         20        3.6
# 1      butaritari   3.0707   172.79    26.65       82         85       8.85
# 2          albany  42.6001 -73.9662     2.78       60        100       3.92
# 3        hermanus -34.4187  19.2345       20       76         76       0.45
# 4         mataura -46.1927  168.864     6.63       95        100       4.53
# ..            ...      ...      ...      ...      ...        ...        ...
# 557  constitucion -35.3333 -72.4167     20.8       63         12       3.03
# 558        pueblo  38.2545 -104.609     1.67       69         20       4.63
# 559    ngaoundere   7.3167  13.5833    19.54       24          0       2.61
# 560     les cayes     18.2   -73.75    27.83       66        100        3.1
# 561         kitob  39.0843  66.8332        9       53          0       2.06
#
#     Country        Date
# 0        US  1611084222
# 1        KI  1611084222
# 2        US  1611084222
# 3        ZA  1611084222
# 4        NZ  1611084222
# ..      ...         ...
# 557      CL  1611084056
# 558      US  1611084271
# 559      CM  1611084271
# 560      HT  1611084271
# 561      UZ  1611084271
#
# [562 rows x 9 columns]

# %%
city_weather_df.dtypes
# Out:
# City          object
# Lat           object
# Lng           object
# Max_Temp      object
# Humidity      object
# Cloudiness    object
# Wind_Speed    object
# Country       object
# Date          object
# dtype: object

# %%
city_weather_df[["Lat","Lng","Max_Temp","Humidity","Cloudiness", "Wind_Speed"]]=city_weather_df[["Lat","Lng","Max_Temp","Humidity","Cloudiness", "Wind_Speed"]].astype("int64")
city_weather_df.dtypes
# Out:
# City          object
# Lat            int64
# Lng            int64
# Max_Temp       int64
# Humidity       int64
# Cloudiness     int64
# Wind_Speed     int64
# Country       object
# Date          object
# dtype: object

# %%
city_weather_df[["Lat","Lng","Max_Temp","Humidity","Cloudiness", "Wind_Speed"]].describe()
# Out:
#               Lat         Lng    Max_Temp    Humidity  Cloudiness  Wind_Speed
# count  562.000000  562.000000  562.000000  562.000000  562.000000  562.000000
# mean    18.914591   17.110320   10.156584   70.934164   54.090747    3.443060
# std     33.322491   89.945866   18.362668   19.981121   41.279759    2.766195
# min    -54.000000 -175.000000  -49.000000    1.000000    0.000000    0.000000
# 25%     -8.000000  -61.750000   -1.000000   60.000000    3.000000    1.000000
# 50%     20.000000   17.500000   16.000000   75.000000   67.500000    3.000000
# 75%     48.000000   98.750000   25.000000   86.000000   98.750000    5.000000
# max     78.000000  179.000000   36.000000  100.000000  100.000000   13.000000

# %%
city_weather_df.to_csv("city_weather.csv", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
Humidity=city_weather_df.loc[city_weather_df['Humidity'] >= 100]
Humidity
# Out:
#               City  Lat  Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 104     hambantota    6   81        24       100          75           0
# 133          patti   31   74        10       100          90           1
# 173       plouzane   48   -4        10       100          90          11
# 233        bairiki    1  172        25       100          75           3
# 284      alyangula  -13  136        25       100          40           2
# 357         balint   45   21        -1       100         100           4
# 470  mount gambier  -37  140         6       100           0           3
# 474          airai   -8  125        16       100         100           1
# 555       penzance   50   -5        11       100          90          13
#
#     Country        Date
# 104      LK  1611084231
# 133      IN  1611084233
# 173      FR  1611084237
# 233      KI  1611084242
# 284      AU  1611084246
# 357      RO  1611084200
# 470      AU  1611084262
# 474      TL  1611084263
# 555      GB  1611084270

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data=city_weather_df.loc[city_weather_df["Humidity"]<=100]
clean_city_data
# Out:
#              City  Lat  Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 0         kahului   20 -156        22        73          20           3
# 1      butaritari    3  172        26        82          85           8
# 2          albany   42  -73         2        60         100           3
# 3        hermanus  -34   19        20        76          76           0
# 4         mataura  -46  168         6        95         100           4
# ..            ...  ...  ...       ...       ...         ...         ...
# 557  constitucion  -35  -72        20        63          12           3
# 558        pueblo   38 -104         1        69          20           4
# 559    ngaoundere    7   13        19        24           0           2
# 560     les cayes   18  -73        27        66         100           3
# 561         kitob   39   66         9        53           0           2
#
#     Country        Date
# 0        US  1611084222
# 1        KI  1611084222
# 2        US  1611084222
# 3        ZA  1611084222
# 4        NZ  1611084222
# ..      ...         ...
# 557      CL  1611084056
# 558      US  1611084271
# 559      CM  1611084271
# 560      HT  1611084271
# 561      UZ  1611084271
#
# [562 rows x 9 columns]

# %%
clean_city_data.to_csv("clean_city_data.csv", index=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values= city_weather_df["Lat"]
y_values= city_weather_df["Max_Temp"]
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Max Temperature')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values=city_weather_df["Lat"]
y_values=city_weather_df["Humidity"]
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (%)")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Humidity (%)')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values=city_weather_df["Lat"]
y_values=city_weather_df["Cloudiness"]
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs.Cloudiness")
# Out:
# Text(0.5, 1.0, 'City Latitude vs.Cloudiness')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values=city_weather_df["Lat"]
y_values=city_weather_df["Wind_Speed"]
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitude vs. Wind Speed")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Wind Speed')

# %% [markdown]
# ## Linear Regression

# %%
from scipy.stats import linregress

# %%
northern=city_weather_df.loc[city_weather_df['Lat'] >=0 ]
southern=city_weather_df.loc[city_weather_df['Lat'] <=0.1]
southern.head()
# Out:
#         City  Lat  Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed Country  \
# 3   hermanus  -34   19        20        76          76           0      ZA
# 4    mataura  -46  168         6        95         100           4      NZ
# 5     castro  -24  -50        21        89         100           4      BR
# 8      vaini  -21 -175        26        94          40           1      TO
# 9  carnarvon  -24  113        25        88          40           7      AU
#
#          Date
# 3  1611084222
# 4  1611084222
# 5  1611084222
# 8  1611084223
# 9  1611084223

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=northern["Lat"]
y_values=northern["Max_Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values*slope+intercept
print(f"The r-squared is:{rvalue**2}")
line_eq="y="+str(round(slope,2))+"X +"+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max_Temp")
plt.show()
# Out:
# The r-squared is:0.7099756713375183

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=southern["Lat"]
y_values=southern["Max_Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values*slope+intercept
print(f"The r-squared is:{rvalue**2}")
line_eq="y="+str(round(slope,2))+"X +"+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()
# Out:
# The r-squared is:0.2667966832319413

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values=northern["Lat"]
y_values=northern["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values*slope+intercept
print(f"The r-squared is:{rvalue**2}")
line_eq="y="+str(round(slope,2))+"X +"+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()
# Out:
# The r-squared is:0.13284547476319727

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values=southern["Lat"]
y_values=southern["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values*slope+intercept
print(f"The r-squared is:{rvalue**2}")
line_eq="y="+str(round(slope,2))+"X +"+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()
# Out:
# The r-squared is:0.09299443557210012

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values=northern["Lat"]
y_values=northern["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values*slope+intercept
print(f"The r-squared is:{rvalue**2}")
line_eq="y="+str(round(slope,2))+"X +"+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()
# Out:
# The r-squared is:0.06393144658972057

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values=southern["Lat"]
y_values=southern["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values*slope+intercept
print(f"The r-squared is:{rvalue**2}")
line_eq="y="+str(round(slope,2))+"X +"+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()
# Out:
# The r-squared is:0.13236681696528665

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values=northern["Lat"]
y_values=northern["Wind_Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values*slope+intercept
print(f"The r-squared is:{rvalue**2}")
line_eq="y="+str(round(slope,2))+"X +"+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()
# Out:
# The r-squared is:0.000889281952061778

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values=southern["Lat"]
y_values=southern["Wind_Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values*slope+intercept
print(f"The r-squared is:{rvalue**2}")
line_eq="y="+str(round(slope,2))+"X +"+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()
# Out:
# The r-squared is:0.07804613685725721
